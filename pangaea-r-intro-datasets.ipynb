# %% [markdown]
# # Working with data from PANGAEA
# We show the use of R packages for PANGAEA datasets. We are usinga a combined CTD dataset  https://doi.pangaea.de/10.1594/PANGAEA.860066.

# %% [markdown]
# ## Using pangaear
# pangaear is a library provided by ropensci. See https://ropensci.org/tutorials/pangaear_tutorial/ and https://github.com/ropensci/pangaear.

# %%
install.packages("pangaear")
library("pangaear")
# Out:
# Installing package into ‘/home/edvs1/rkoppe/R/x86_64-pc-linux-gnu-library/3.4’
# (as ‘lib’ is unspecified)

# %%
res <- pg_data(doi = '10.1594/PANGAEA.860066', overwrite = FALSE)
#res[[1]]
# Out:
# Downloading 1 datasets from 10.1594/PANGAEA.860066
# Processing 1 files

# %%
str(res)
# Out:
# List of 1
#  $ :List of 6
#   ..$ parent_doi: chr "10.1594/PANGAEA.860066"
#   ..$ doi       : chr "10.1594/PANGAEA.860066"
#   ..$ citation  : chr NA
#   ..$ url       : chr "https://doi.org/10.1594/PANGAEA.860066"
#   ..$ path      : chr "/home/edvs1/rkoppe/.cache/pangaear/10_1594_PANGAEA_860066.txt"
#   ..$ data      :Classes ‘tbl_df’, ‘tbl’ and 'data.frame':	131 obs. of  13 variables:
#   .. ..$ Campaign (cruise leg, ANT/ARK notation): chr [1:131] "ANT-II/3" "ANT-II/4" "ANT-III/3" "ANT-V/1" ...
#   .. ..$ Campaign (cruise leg, PS notation)     : chr [1:131] "PS04" "PS04" "PS06" "PS09" ...
#   .. ..$ Date/time start                        : chr [1:131] "1983-11-22" "1983-12-28" "1985-01-03" "1986-05-06" ...
#   .. ..$ Date/time end                          : chr [1:131] "1983-12-27" "1984-03-09" "1985-03-05" "1986-06-19" ...
#   .. ..$ Author(s)                              : chr [1:131] "Rohardt, G" "Rohardt, G" "Rohardt, G" "Stein, M" ...
#   .. ..$ PI                                     : chr [1:131] "Rohardt, G" "Rohardt, G" "Rohardt, G" "Stein, M" ...
#   .. ..$ NOBS [#]                               : int [1:131] 34 33 116 101 152 99 35 81 18 23 ...
#   .. ..$ Method comm                            : chr [1:131] "CTD, Neil Brown, Mark III B" "CTD, Neil Brown, Mark III B / Nansen bottles" "CTD, Neil Brown, Mark III B" "CTD, ME-OTS-CTD" ...
#   .. ..$ OS region                              : chr [1:131] "Antarctic Peninsula" "Weddell Sea" "Weddell Sea" "Antarctic Peninsula" ...
#   .. ..$ Persistent Identifier                  : chr [1:131] "http://dx.doi.org/10.1594/PANGAEA.734969" "http://dx.doi.org/10.1594/PANGAEA.734972" "http://dx.doi.org/10.1594/PANGAEA.734977" "http://dx.doi.org/10.1594/PANGAEA.734980" ...
#   .. ..$ Quality                                : chr [1:131] "C" "C" "B" "C" ...
#   .. ..$ URL image                              : chr [1:131] "http://store.pangaea.de/Publications/Rohardt-etal_2016/ANT-II-3.png" "http://store.pangaea.de/Publications/Rohardt-etal_2016/ANT-II-4.png" "http://store.pangaea.de/Publications/Rohardt-etal_2016/ANT-III-3.png" "http://store.pangaea.de/Publications/Rohardt-etal_2016/ANT-V-1.png" ...
#   .. ..$ URL ref                                : chr [1:131] "doi:10.2312/BzP_0018_1984" "doi:10.2312/BzP_0019_1984" "doi:10.2312/BzP_0025_1985" "doi:10.2312/BzP_0039_1987" ...
#   ..- attr(*, "class")= chr "pangaea"

# %%
data <- as.data.frame(res[[1]]$data)
#data

# %%
head(data)
# Out:
#   Campaign (cruise leg, ANT/ARK notation) Campaign (cruise leg, PS notation)
# 1 ANT-II/3                                PS04
# 2 ANT-II/4                                PS04
# 3 ANT-III/3                               PS06
# 4 ANT-V/1                                 PS09
# 5 ANT-V/2                                 PS10
# 6 ANT-V/3                                 PS10
#   Date/time start Date/time end Author(s)               PI         NOBS [#]
# 1 1983-11-22      1983-12-27    Rohardt, G              Rohardt, G  34
# 2 1983-12-28      1984-03-09    Rohardt, G              Rohardt, G  33
# 3 1985-01-03      1985-03-05    Rohardt, G              Rohardt, G 116
# 4 1986-05-06      1986-06-19    Stein, M                Stein, M   101
# 5 1986-06-27      1986-09-17    Gordon, AL              Gordon, AL 152
# 6 1986-09-29      1986-12-14    Fahrbach, E; Rohardt, G Rohardt, G  99
#   Method comm                                  OS region
# 1 CTD, Neil Brown, Mark III B                  Antarctic Peninsula
# 2 CTD, Neil Brown, Mark III B / Nansen bottles Weddell Sea
# 3 CTD, Neil Brown, Mark III B                  Weddell Sea
# 4 CTD, ME-OTS-CTD                              Antarctic Peninsula
# 5 CTD, Neil Brown, Mark III B                  Weddell Sea, Prime Meridian
# 6 CTD, Neil Brown, Mark III B                  Weddell Sea, Prime Meridian
#   Persistent Identifier                    Quality
# 1 http://dx.doi.org/10.1594/PANGAEA.734969 C
# 2 http://dx.doi.org/10.1594/PANGAEA.734972 C
# 3 http://dx.doi.org/10.1594/PANGAEA.734977 B
# 4 http://dx.doi.org/10.1594/PANGAEA.734980 C
# 5 http://dx.doi.org/10.1594/PANGAEA.734981 B
# 6 http://dx.doi.org/10.1594/PANGAEA.735189 B
#   URL image
# 1 http://store.pangaea.de/Publications/Rohardt-etal_2016/ANT-II-3.png
# 2 http://store.pangaea.de/Publications/Rohardt-etal_2016/ANT-II-4.png
# 3 http://store.pangaea.de/Publications/Rohardt-etal_2016/ANT-III-3.png
# 4 http://store.pangaea.de/Publications/Rohardt-etal_2016/ANT-V-1.png
# 5 http://store.pangaea.de/Publications/Rohardt-etal_2016/ANT-V-2.png
# 6 http://store.pangaea.de/Publications/Rohardt-etal_2016/ANT-V-3.png
#   URL ref
# 1 doi:10.2312/BzP_0018_1984
# 2 doi:10.2312/BzP_0019_1984
# 3 doi:10.2312/BzP_0025_1985
# 4 doi:10.2312/BzP_0039_1987
# 5 doi:10.2312/BzP_0039_1987
# 6 doi:10.2312/BzP_0039_1987

# %% [markdown]
# Download all referenced dataset files and select columns.

# %%
pids <- data[,"Persistent Identifier"]

# Setup data frame
master <- data.frame() #datetime = c(), depth = c(), temperature = c())

for (pid in pids) {
    pid <- gsub('.*10.1594', '10.1594', pid)
    res <- pg_data(doi = pid, overwrite = FALSE, mssgs = FALSE)
    d <- as.data.frame(res[[1]]$data)
    
    if (all(c("Date/Time", "Latitude", "Longitude", "Depth water [m]", "Temp [°C]") %in% colnames(d))) {
        df <- data.frame(
            datetime = as.POSIXct(d[,"Date/Time"], format = "%Y-%m-%dT%H:%M"),
            latitude = d[,"Latitude"],
            longitude = d[,"Longitude"],
            depth = d[,"Depth water [m]"],
            temperature = d[,"Temp [°C]"])    

        master = rbind(master, df)
    } else {
        print(sprintf("Dataset %s does not contain required columns.", pid))
    }
}
# Out:
# Downloading 1 datasets from 10.1594/PANGAEA.734969
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.734972
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.734977
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.734980
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.734981
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.735189
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.734988
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.742653
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.484267
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.742578
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.742613
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.92067
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.742579
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.742615
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.742580
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.735590
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.735277
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.742577
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.742616
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.738488
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.735278
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.759261
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.742651
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.751507
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.752256
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.752257
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.742586
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.735279
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.666532
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.735281
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.752258
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.752213
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.742581
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.742953
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.751508
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.752259
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.735282
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.756513
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.738489
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.742617
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.61240
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.742654
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.753132
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.756514
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.742626
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.742655
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.735530
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.742582
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.753142
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.743082
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.742657
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.95076
# Processing 1 files
# [1] "Dataset 10.1594/PANGAEA.95076 does not contain required columns."
# Downloading 1 datasets from 10.1594/PANGAEA.756515
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.60093
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.753134
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.742658
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.742583
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.742584
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.735574
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.742585
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.742619
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.67027
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.72320
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.756516
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.753139
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.742620
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.738486
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.759270
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.733415
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.772615
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.733416
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.742656
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.756517
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.733410
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.772927
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.742660
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.733664
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.742621
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.733336
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.735610
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.499806
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.733348
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.733423
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.735531
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.733335
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.733417
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.733418
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.733665
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.733414
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.742855
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.772614
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.733424
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.733425
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.744706
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.744707
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.742652
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.772158
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.753658
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.744710
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.744711
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.754248
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.758127
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.754249
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.754250
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.772138
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.772244
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.770000
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.774196
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.78140
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.774181
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.840334
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.801791
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.800427
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.802904
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.817254
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.817255
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.811907
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.857302
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.819714
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.836537
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.833299
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.837425
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.846701
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.861865
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.863064
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.863807
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.859561
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.859558
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.859015
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.859016
# Processing 1 files
# Downloading 1 datasets from 10.1594/PANGAEA.859040
# Processing 1 files

# %% [markdown]
# Show statistics.

# %%
summary(master)
# Out:
#     datetime                      latitude          longitude
#  Min.   :1983-11-25 16:43:00   Min.   :-77.9198   Min.   :-179.9473
#  1st Qu.:1998-02-05 11:36:00   1st Qu.:-63.7167   1st Qu.: -18.1250
#  Median :2004-06-29 01:24:00   Median :-49.1955   Median :  -0.0467
#  Mean   :2003-05-30 20:55:52   Mean   : -0.2326   Mean   :  -3.3650
#  3rd Qu.:2009-11-16 00:24:00   3rd Qu.: 78.3322   3rd Qu.:   5.3195
#  Max.   :2016-02-08 01:14:00   Max.   : 89.9867   Max.   : 179.9320
#
#      depth           temperature
#  Min.   :  -0.373   Min.   :-999.000
#  1st Qu.: 480.400   1st Qu.:  -0.716
#  Median :1262.900   Median :  -0.148
#  Mean   :1530.046   Mean   :   0.323
#  3rd Qu.:2336.400   3rd Qu.:   0.731
#  Max.   :6205.600   Max.   :  29.740
#                     NA's   :8400

# %% [markdown]
# Fix up -999 temperature values. Temperature is unknown.

# %%
df <- master
df[which(df$temperature == -999), "temperature"] = NA
summary(df)
# Out:
#     datetime                      latitude          longitude
#  Min.   :1983-11-25 16:43:00   Min.   :-77.9198   Min.   :-179.9473
#  1st Qu.:1998-02-05 11:36:00   1st Qu.:-63.7167   1st Qu.: -18.1250
#  Median :2004-06-29 01:24:00   Median :-49.1955   Median :  -0.0467
#  Mean   :2003-05-30 20:55:52   Mean   : -0.2326   Mean   :  -3.3650
#  3rd Qu.:2009-11-16 00:24:00   3rd Qu.: 78.3322   3rd Qu.:   5.3195
#  Max.   :2016-02-08 01:14:00   Max.   : 89.9867   Max.   : 179.9320
#
#      depth           temperature
#  Min.   :  -0.373   Min.   :-10.000
#  1st Qu.: 480.400   1st Qu.: -0.716
#  Median :1262.900   Median : -0.148
#  Mean   :1530.046   Mean   :  0.328
#  3rd Qu.:2336.400   3rd Qu.:  0.731
#  Max.   :6205.600   Max.   : 29.740
#                     NA's   :8471

# %% [markdown]
# Create the plot. Takes some time...

# %%
library(ggplot2)
library(scales)

gg <- ggplot(df, aes(datetime, depth)) +
    geom_point(aes(col = temperature)) +
    labs(title = "Temperature at depths", x = "datetime", y = "~ depth [m]") +
    scale_color_gradientn(colors = rev(rainbow(5)), name = "Temp [°C]") +
    scale_x_datetime(labels = date_format("%Y-%m-%d"), date_breaks = "7 days") +
    scale_y_reverse()

options(repr.plot.width = 10, repr.plot.height = 5)
plot(gg)
# Out:
# plot without title

# %% [markdown]
# Prepare some temperature per depth plots on a "map".

# %%
d0001 <- df[which(df$depth <= 1),]
d0010 <- df[which(df$depth <= 10),]
d0100 <- df[which(df$depth <= 100),]

# %%
ggplot() +
    geom_point(data = d0001, aes(x = longitude, y = latitude, col = temperature), size = 2) +
    scale_color_gradientn(colors = rev(rainbow(5)), name = "Temp [°C]") +
    labs(title = "Temperature in <= 1m depths")
# Out:
# plot without title

# %%
ggplot() +
    geom_point(data = d0010, aes(x = longitude, y = latitude, col = temperature), size = 2) +
    scale_color_gradientn(colors = rev(rainbow(5)), name = "Temp [°C]") +
    labs(title = "Temperature in <= 10m depths")
# Out:
# plot without title

# %%
ggplot() +
    geom_point(data = d0100, aes(x = longitude, y = latitude, col = temperature), size = 2) +
    scale_color_gradientn(colors = rev(rainbow(5)), name = "Temp [°C]") +
    labs(title = "Temperature in <= 100m depths")
# Out:
# plot without title
